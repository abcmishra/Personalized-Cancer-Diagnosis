# %% [markdown]
# # Model Performance Table

# %% [markdown]
# <html>
# <head>
# <style>
# table {
#     font-family: arial, sans-serif;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;
# }
#
# tr:nth-child(even) {
#     background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h2>Log Loss Table</h2>
#
# <table>
#   <tr>
#     <th>Model Name</th>
#     <th>Train Error</th>
#     <th>Cross Validation Error</th>
#     <th>Test Error</th>
#     <th>Missclassified Points</th>
#
#   </tr>
#   <tr>
#     <td>Random Model</td>
#     <td>Nill</td>
#     <td>2.42</td>
#     <td>2.50</td>
#     <td>Nill</td>
#   </tr>
#   <tr>
#     <td>Naive Bayes</td>
#     <td>0.857</td>
#     <td>1.24</td>
#     <td>1.22</td>
#     <td>0.402</td>
#   </tr>
#   <tr>
#     <td>KNN</td>
#     <td>0.668</td>
#     <td>2.421.011</td>
#     <td>1.00</td>
#     <td>0.370</td>
#   </tr>
#   <tr>
#     <td><b>Logistic Regression with Balancing </td>
#     <td><b>0.583</td>
#     <td><b>1.080</td>
#     <td><b>1.059</td>
#     <td><b>0.3496</td>
#   </tr>
#   <tr>
#     <td>Logistic Regresion without balancing</td>
#     <td>0.625</td>
#     <td>1.252</td>
#     <td>1.130</td>
#     <td>0.3721</td>
#   </tr>
#   <tr>
#     <td>Linear Support Vector Machine</td>
#     <td>0.667</td>
#     <td>1.126</td>
#     <td>1.088</td>
#     <td>0.360</td>
#   </tr>
#   <tr>
#     <td>Random Forest with tfidf </td>
#     <td>0.708</td>
#     <td>1.160</td>
#     <td>1.152</td>
#     <td>0.368</td>
#   </tr>
#   <tr>
#     <td>Random Forest with Respose coding</td>
#     <td>0.058</td>
#     <td>1.240</td>
#     <td>1.237</td>
#     <td>0.432</td>
#   </tr>
#   <tr>
#     <td>Stack Models</td>
#     <td>0.637</td>
#     <td>1.113</td>
#     <td>1.124</td>
#     <td>0.3518</td>
#   </tr>
#   <tr>
#     <td>Maximum Voting Classifier</td>
#     <td>0.85</td>
#     <td>1.67</td>
#     <td>1.56</td>
#     <td>0.36</td>
#   </tr>
# <tr>
#     <td>Logistic Regression with Bi-Grams with Class balancing</td>
#     <td>0.66</td>
#     <td>1.27</td>
#     <td>1.21</td>
#     <td>0.43</td>
#   </tr>
# <tr>
#     <td>Logistic Regression with Bi-Grams without Class balancing</td>
#     <td>0.808</td>
#     <td>1.248</td>
#     <td>1.217</td>
#     <td>0.417</td>
#   </tr>
# <tr>
#     <td>Logistic Regression with Four-Grams with Class balancing</td>
#     <td>0.700</td>
#     <td>1.277</td>
#     <td>1.231</td>
#     <td>0.430</td>
#   </tr>
# <tr>
#     <td>Logistic Regression with Four-Grams without Class balancing</td>
#     <td>0.705</td>
#     <td>1.253</td>
#     <td>1.220</td>
#     <td>0.421</td>
#   </tr>
#
# </table>
#
# </body>
# </html>
